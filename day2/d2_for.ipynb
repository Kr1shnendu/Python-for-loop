# %%
import logging

logging.basicConfig(
    filename="for_loop_questions.log",
    level=logging.INFO,
    format="%(asctime)s - %(lineno)d - %(levelname)s - %(message)s",
    filemode='a'
)

# %%
def count_vowels(s: str) -> int:
    """
    Count the number of vowels in a string
    Parameters:
        s (str): Input string
    Returns:
        int: No of vowels
    """
    vowels = "aeiou"
    count = 0
    for ch in s:
        if(ch.lower() in vowels):
            count+=1

    logging.info(f"number of vowels are: {count}")
    return count

n = count_vowels("agfseio")

# %%
def freq(s: str) -> dict:
    """
    Print the frequency of each character in a string
    Parameters:
        s (str): Input string
    Returns:
        dict: No of vowels
    """
    d = {}

    for ch in s:
        d[ch] = 0

    for ch in s:
        d[ch] = d[ch] + 1
    
    logging.info(f"number of vowels are: {d}")
    return d

freq("helloworld")
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, 'w': 1, 'r': 1, 'd': 1}

# %%
from typing import List
def second_largest_element(l: List[int]) -> int:
    """
    Finds the second largest elements in a list
    Parameters:
        l (List[int]): Input list of integers
    Returns:
        int: Second largest element
    """
    largest = l[0]
    for num in l:
        if(num>largest):
            largest = num
    
    sec_largest = -1
    for num in l:
        if((num != largest) and (num > sec_largest)):
            sec_largest = num

    logging.info(f"The second largest elements in a list is: {sec_largest}")
    return sec_largest

second_largest_element([2, 3, 7, 2, 9, 8, 6])
# Out:
# 8

# %%
from typing import List
def check_sorted(l: List[int]) -> int:
    """
    Checks whether a list is sorted in ascending order
    Parameters:
        l (List[int]): Input list of integers
    Returns:
        bool: True, if the list is sorted in ascending order. Otherwise, False
    """
    copy_l = l.copy()
    copy_l.sort()
    if(l == copy_l):
        logging.info(f"The list: {l} is sorted in ascending order")
        return True
    else:
        logging.info(f"The list: {l} is not sorted ascending order")
        return False

check_sorted([2, 3, 7, 2, 9, 8, 6])
check_sorted([2, 3, 5, 8])
# Out:
# True

# %%
lst = {i:i**2 for i in range(1,11)}
lst
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
lst = [i for i in range(1,11) if(i%2==0)]
lst
# Out:
# [2, 4, 6, 8, 10]

# %%
lst = [i**2 if i%2==0 else i**3 for i in range(1,11)]
lst
# Out:
# [1, 4, 27, 16, 125, 36, 343, 64, 729, 100]

# %%
inp = "Python is very very easy language"

lst = {s: len(s) for s in inp.split(' ')}
lst
# Out:
# {'Python': 6, 'is': 2, 'very': 4, 'easy': 4, 'language': 8}

# %%
lst = [(s.lower(), len(s)) for s in inp.split(' ')]
lst
# Out:
# [('python', 6),
#  ('is', 2),
#  ('very', 4),
#  ('very', 4),
#  ('easy', 4),
#  ('language', 8)]

# %%
inp = "Hai HeLLO"

d = {ch: ord(ch) for ch in inp if ch.isupper()}
d
# Out:
# {'H': 72, 'L': 76, 'O': 79}
