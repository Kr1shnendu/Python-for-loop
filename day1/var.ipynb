# %%
a = 21 + 3j
id(a)
# Out:
# 1577620601616

# %%
type(a)
# Out:
# complex

# %%
int()
# Out:
# 0

# %%
float()
# Out:
# 0.0

# %%
complex()
# Out:
# 0j

# %%
bool()
# Out:
# False

# %%
b = None
type(b)
# Out:
# NoneType

# %%
# NoneType()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 NoneType()
#
# NameError: name 'NoneType' is not defined

# %%
s = 'hit'
id(s)
# Out:
# 1577578092016

# %%
type(s)
# Out:
# str

# %%
str()
# Out:
# ''

# %%
def demo():
    '''this function returns 5'''
    print(2+3)

# %%
demo()
# Out:
# 5

# %%
def sub(a: int, b: int) -> int: #type hinting
    return a-b

# %%
a: float = 10.4
b: int = 7
sub(a,b)
# Out:
# 3.4000000000000004

# %%
type(a)
# Out:
# float

# %%
s = "Python 123 is a programming language. yes"

# %%
s.upper()
# Out:
# 'PYTHON 123 IS A PROGRAMMING LANGUAGE. YES'

# %%
s.lower()
# Out:
# 'python 123 is a programming language. yes'

# %%
s.capitalize()
# Out:
# 'Python 123 is a programming language. yes'

# %%
s.title()
# Out:
# 'Python 123 Is A Programming Language. Yes'

# %%
s.isupper()
# Out:
# False

# %%
name = 'abc'
name.islower()
# Out:
# True

# %%
dig = '1345'
dig.isdigit()
# Out:
# True

# %%
dig2 = '43 77'
dig2.isdigit()
# Out:
# False

# %%
al = 'hello'
al.isalpha()
# Out:
# True

# %%
al2 = 'hello world'
al2.isalpha()
# Out:
# False

# %%
s1 = 'Python 123 is a programming language'
s1.count('a')
# Out:
# 4

# %%
s1.count('Py')
# Out:
# 1

# %%
s1.count(s1)
# Out:
# 1

# %%
s1.replace('Python', 'Java')
# Out:
# 'Java 123 is a programming language'

# %%
s1.split()
# Out:
# ['Python', '123', 'is', 'a', 'programming', 'language']

# %%
s2 = 'Python-123-is a programming-language'
s2.split('-')
# Out:
# ['Python', '123', 'is a programming', 'language']

# %%
s3 = '   hello        '
s3.strip()
# Out:
# 'hello'

# %%
s3.lstrip()
# Out:
# 'hello        '

# %%
s3.rstrip()
# Out:
# '   hello'

# %% [markdown]
# List

# %%
ls = [1, 2, 3, 4]
type(ls)
# Out:
# list

# %%
id(ls)
# Out:
# 1577629579264

# %%
list()
# Out:
# []

# %%
ls = [1, 'hit']
ls[1] = 'hello'
ls
# Out:
# [1, 'hello']

# %%
ls = [1, 2, 3, 4]
ls.append(5)
ls
# Out:
# [1, 2, 3, 4, 5]

# %%
ls.extend((6, 7)) #collection arg
ls
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
ls.insert(2, 9)
ls
# Out:
# [1, 2, 9, 3, 4, 5, 6, 7]

# %%
ls.insert(-2, 10)
ls
# Out:
# [1, 2, 9, 3, 4, 5, 10, 6, 7]

# %%
ls.remove(10)
ls
# Out:
# [1, 2, 9, 3, 4, 5, 6, 7]

# %%
ls.insert(2, 6)
ls.insert(4, 6)
ls
# Out:
# [1, 2, 6, 9, 6, 3, 4, 5, 6, 7]

# %%
ls.remove(6) #value
ls
# Out:
# [1, 2, 9, 6, 3, 4, 5, 6, 7]

# %%
ls.pop()
ls
# Out:
# [1, 2, 9, 6, 3, 4, 5, 6]

# %%
ls.pop(2) #index
ls
# Out:
# [1, 2, 6, 3, 4, 5, 6]

# %%
ls.index(6)
# Out:
# 2

# %%
ls.index(80)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 ls.index(80)
#
# ValueError: list.index(x): x not in list

# %%
ls.append(3)
ls.append(4)
ls.append(3)
ls
# Out:
# [1, 2, 6, 3, 4, 5, 6, 3, 4, 3]

# %%
ls.count(4)
# Out:
# 2

# %%
ls.sort()
ls
# Out:
# [1, 2, 3, 3, 3, 4, 4, 5, 6, 6]

# %%
ls.reverse()
ls
# Out:
# [6, 6, 5, 4, 4, 3, 3, 3, 2, 1]

# %%
ls.insert(2, 9)
ls.insert(5, 10)
ls
# Out:
# [6, 6, 9, 9, 5, 10, 4, 4, 3, 3, 3, 2, 1]

# %%
ls.sort(reverse=True)
ls
# Out:
# [10, 9, 9, 6, 6, 5, 4, 4, 3, 3, 3, 2, 1]

# %%
ls[1] = 6
ls[-1] = 7
ls
# Out:
# [10, 6, 9, 6, 6, 5, 4, 4, 3, 3, 3, 2, 7]

# %%
t = (1, 2, 3)
type(t)
# Out:
# tuple

# %%
tuple()
# Out:
# ()

# %%
t[1]
# Out:
# 2

# %%
t[1] = 20 #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 t[1] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (1, 2, 1, 12)
t.count(1)
# Out:
# 2

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
d = {'a': 1, 'b': 2}
d
# Out:
# {'a': 1, 'b': 2}

# %%
d['b']
# Out:
# 2

# %%
d2 = {'a': 1, 'b': 2, 'c': 3}
d2
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d2['b']
# Out:
# 2

# %%
d2['bbb']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 d2['bbb']
#
# KeyError: 'bbb'

# %%
d2.get('a')
# Out:
# 1

# %%
d2.get('bbb')

# %%
d2.get('bbb', 0)
# Out:
# 0

# %%
d2.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
d2.values()
# Out:
# dict_values([1, 2, 3])

# %%
d2.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
d2.pop('b')
d2
# Out:
# {'a': 1, 'c': 3}

# %%
d2.clear()
d2
# Out:
# {}

# %%
print("ok")
# Out:
# ok
